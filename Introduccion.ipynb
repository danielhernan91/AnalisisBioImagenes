# %% [markdown]
# # GENERALIDADES

# %% [markdown]
# * Las imágenes están compuestas por píxeles. La palabra 'píxel' deriva de la expresión inglesa picture element (elemento de imagen)
# * Las imágenes que parecen iguales pueden contener diferentes valores de píxeles.
# Las imágenes que parecen diferentes aún pueden contener los mismos valores de píxeles. 8bits,16bits,32bits
# * Tablas de búsqueda (LUTs). Las tablas de búsqueda a veces se denominan mapas de colores. El software que muestra la imagen utiliza una tabla de búsqueda (LUT) que asigna cada valor de píxel a un color.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np 
import matplotlib.patches as patches

# Cargar una imagen y seleccionar una región detallada
im = mpimg.imread('imagen.tif') # Use mpimg.imread()
x, y, width, height = (205, 100, 120, 120)
im_detail = im[y:y+height, x:x+width]

# Mostrar gráficos
fig = plt.figure(figsize=(8, 4)) 

# Crear un rectángulo para resaltar la región seleccionada
rect = patches.Rectangle((x, y), width, height, linewidth=1, edgecolor='r', facecolor='none')

# Mostrar la imagen original
plt.subplot(131)
plt.imshow(im, vmin=0, vmax=255) 
plt.title('(A) Imagen original')
plt.gca().add_patch(rect) # Añadir el rectángulo a la imagen original

# Mostrar la vista ampliada de la región seleccionada
plt.subplot(132)
plt.imshow(im_detail, vmin=0, vmax=255)
plt.title('(B) Vista ampliada de (A)')

# Mostrar los valores de píxeles de la región ampliada
plt.subplot(133)
plt.imshow(im_detail, vmin=0, vmax=255, alpha=1)
plt.title('(C) Valores de píxeles de (B)')

# Anotar cada píxel con su valor numérico
for (i, j), z in np.ndenumerate(im_detail):
    plt.text(j, i, str(z), ha='center', va='center', fontdict={'size': 5})

plt.tight_layout() 
plt.show()

# %%
# Lectura sencilla de imagenes (png,tif) con una tabla de busqueda LUTS
import matplotlib.pyplot as plt
from imageio import imread 
im = imread('imagen.tif')
plt.imshow(im)
plt.title ('Importacion de Imagnes de Microscopia')
plt.show()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_14288\3490041951.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread('imagen.tif')

# %%
# Visualizacion en escala de grises, Cambiando LUTS
#cmap: cambia el mapa de colores (LUT)
plt.imshow(im, cmap='gray')
plt.show()

# %%
plt.imshow(im, cmap='gray_r')
plt.show()

# %% [markdown]
# Los valores en los ejes X e Y representan las dimensiones de la imagen en píxeles.
# - El eje X representa la posición horizontal (columnas de píxeles).
#
# - El eje Y representa la posición vertical (filas de píxeles).
#
#
# - 'cmap='gray'' fuerza la imagen a escala de grises.
# - 'vmin=100' establece que cualquier píxel con valor 100 o menos se mostrará como el color más oscuro (negro).
# - 'vmax=255' establece que cualquier píxel con valor 255 o más se mostrará como el color más claro (blanco).
# - Los píxeles entre 100 y 255 se escalarán linealmente a los tonos de gris intermedios.

# %%
plt.imshow(im, cmap='gray', vmin=100, vmax=255)
plt.show()

# %%
plt.imshow(im, cmap='gray', vmin=0, vmax=100)
plt.show()

# %%
plt.imshow(im, cmap='magma')
plt.show()

# %%
plt.imshow(im, cmap='hsv')
plt.show()

# %% [markdown]
# Desactivando el eje exterior y uso una tabla de búsqueda en escala de grises.

# %%
# 
im = imread('imagen.tif')
plt.imshow(im, cmap='gray') 
plt.axis(False)
plt.title('Imagen de Muestra')
plt.show()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_14288\4016636681.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imread('imagen.tif')
